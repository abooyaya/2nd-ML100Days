# %% [markdown]
# # Hierarchical clustering with 2D toy datasets

# %% [markdown]
# # [作業目標]
# - 將階層式聚類套用在 2D 樣板資料上, 來觀察幾種不同參數的結果有何不同

# %% [markdown]
# # [作業重點]
# - 以幾種 2D 樣板資料, 觀察階層式聚類在 "linkage參數" 有所不同時, 分群的效果如何變化 (In[4], Out[4])# [作業重點]
# - 以幾種 2D 樣板資料, 觀察階層式聚類在 "linkage參數" 有所不同時, 分群的效果如何變化 (In[4], Out[4])

# %%
# 載入套件
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

# %%
# 設定 2D 樣板資料
n_samples = 1500
random_state = 100

# 生成 雙半月 資料點
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)

# 生成 緊密三群 資料點
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)

# 生成 2維均勻分布 資料點
no_structure = np.random.rand(n_samples, 2), None

# %%
# 設定群集與繪圖參數
plt.figure(figsize=(10, 20))
default_base = {'n_neighbors': 10, 'n_clusters': 3}
datasets = [(noisy_moons, {'n_clusters': 3}), (blobs, {}), (no_structure, {})]

# %% [markdown]
# # 作業
# * 試著完成剩下三種 2D 樣板資料的繪圖, 並觀察有何不同

# %%
plot_num = 1
# 執行各種樣板資料的繪圖迴圈
params = default_base.copy()
params.update(datasets[0][1]) 
#取得 雙半月 資料點
X, y = datasets[0][0]
X = StandardScaler().fit_transform(X)

# 設定三種不同參數的 Hierarchical clustering
ward = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="ward")
complete = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="complete")
average = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="average")
clustering_algorithms = (
    ('Average Linkage', average),
    ('Complete Linkage', complete),
    ('Ward Linkage', ward))

# 繪製三種圖形
for name, algorithm in clustering_algorithms:
    # t0 / t1 : 紀錄時間差
    t0 = time.time()    
    algorithm.fit(X)
    t1 = time.time()

    #分類結果
    if hasattr(algorithm, 'labels_'):
        y_pred = algorithm.labels_.astype(np.int)
    else:
        y_pred = algorithm.predict(X)

    #row, col, num    
    plt.subplot(3, 1, plot_num)
    
    plt.title("Test", size=18)
    
    colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
    #畫雙月圖
    plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])
    
    plt.xlim(-2.5, 2.5)
    plt.ylim(-2.5, 2.5)
        
    plt.xticks(())
    plt.yticks(())
    
    plot_num += 1
    
plt.show()

# %%
plot_num = 1
# 執行各種樣板資料的繪圖迴圈
params = default_base.copy()
params.update(datasets[0][1]) 
#取得 雙半月 資料點
X, y = datasets[1][0]
X = StandardScaler().fit_transform(X)

# 設定三種不同參數的 Hierarchical clustering
ward = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="ward")
complete = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="complete")
average = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="average")
clustering_algorithms = (
    ('Average Linkage', average),
    ('Complete Linkage', complete),
    ('Ward Linkage', ward))

# 繪製三種圖形
for name, algorithm in clustering_algorithms:
    # t0 / t1 : 紀錄時間差
    t0 = time.time()    
    algorithm.fit(X)
    t1 = time.time()

    #分類結果
    if hasattr(algorithm, 'labels_'):
        y_pred = algorithm.labels_.astype(np.int)
    else:
        y_pred = algorithm.predict(X)

    #row, col, num    
    plt.subplot(3, 1, plot_num)
    
    plt.title("Test", size=18)
    
    colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
    #畫雙月圖
    plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])
    
    plt.xlim(-2.5, 2.5)
    plt.ylim(-2.5, 2.5)
        
    plt.xticks(())
    plt.yticks(())
    
    plot_num += 1
    
plt.show()

# %%
plot_num = 1
# 執行各種樣板資料的繪圖迴圈
params = default_base.copy()
params.update(datasets[0][1]) 
#取得 雙半月 資料點
X, y = datasets[2][0]
X = StandardScaler().fit_transform(X)

# 設定三種不同參數的 Hierarchical clustering
ward = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="ward")
complete = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="complete")
average = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="average")
clustering_algorithms = (
    ('Average Linkage', average),
    ('Complete Linkage', complete),
    ('Ward Linkage', ward))

# 繪製三種圖形
for name, algorithm in clustering_algorithms:
    # t0 / t1 : 紀錄時間差
    t0 = time.time()    
    algorithm.fit(X)
    t1 = time.time()

    #分類結果
    if hasattr(algorithm, 'labels_'):
        y_pred = algorithm.labels_.astype(np.int)
    else:
        y_pred = algorithm.predict(X)

    #row, col, num    
    plt.subplot(3, 1, plot_num)
    
    plt.title("Test", size=18)
    
    colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
    #畫雙月圖
    plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])
    
    plt.xlim(-2.5, 2.5)
    plt.ylim(-2.5, 2.5)
        
    plt.xticks(())
    plt.yticks(())
    
    plot_num += 1
    
plt.show()

# %%
print(datasets[0][1])
print(datasets[0][0])
print(datasets[0][0][0])
print(datasets[0][0][1])
# Out:
# {'n_clusters': 2}
# (array([[-0.03162046,  0.46817624],
#        [ 1.94788601,  0.225074  ],
#        [ 0.80861361, -0.46350415],
#        ...,
#        [ 1.2518344 , -0.44379682],
#        [-0.49889777,  0.83126715],
#        [-0.9009966 ,  0.44524966]]), array([1, 1, 1, ..., 1, 0, 0]))
# [[-0.03162046  0.46817624]
#  [ 1.94788601  0.225074  ]
#  [ 0.80861361 -0.46350415]
#  ...
#  [ 1.2518344  -0.44379682]
#  [-0.49889777  0.83126715]
#  [-0.9009966   0.44524966]]
# [1 1 1 ... 1 0 0]

# %%
datasets[1][0]
# Out:
# (array([[ 5.86749807,  8.17715188],
#         [ 5.61369982,  9.93295527],
#         [ 7.22508428, 10.44886194],
#         ...,
#         [ 7.73674097, 10.82855388],
#         [-4.61701094, -9.64855983],
#         [-3.48640175, -9.25766922]]), array([0, 0, 0, ..., 0, 2, 2]))
